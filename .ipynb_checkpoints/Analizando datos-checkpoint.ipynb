# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('./Datasets/data_regression.csv', index_col = False)
print(df.info())

x_1 = df['X1']
x_2 = df['X2']
x_3 = df['X3']
y = df['y']
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1500 non-null   int64
#  1   X1          1500 non-null   float64
#  2   X2          1500 non-null   float64
#  3   X3          1500 non-null   float64
#  4   y           1500 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 58.7 KB
# None
#       Unnamed: 0         X1         X2        X3          y
# 0              0 -10.000000   0.000000 -5.000000  10.958481
# 1              1  -9.986658   0.014676 -4.996664   8.991666
# 2              2  -9.973316   0.029353 -4.993329  10.398068
# 3              3  -9.959973   0.044029 -4.989993  11.759961
# 4              4  -9.946631   0.058706 -4.986658  10.177304
# ...          ...        ...        ...       ...        ...
# 1495        1495   9.946631  21.941294 -0.013342   1.208277
# ...

# %%
#help(pd.read_csv)

# %%
### Train test split con respecto a x_1
X_train, X_test, y_train, y_test = train_test_split(x_1, y, test_size = 0.2, random_state = 42)

print('Cantidad de datos separados:\n')
print('X_train: ',X_train.shape)
print('X_test: ',X_test.shape)
print('y_train: ',y_train.shape)
print('X_test: ',y_test.shape)
print('###############')
lin_model = LinearRegression()
X_train = np.array(X_train).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
lin_model.fit(X_train, y_train)
# Out:
# Cantidad de datos separados:
#
# X_train:  (1200,)
# X_test:  (300,)
# y_train:  (1200,)
# X_test:  (300,)
# ###############
# LinearRegression()

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1200, 1)
# (1200, 1)

# %%
print('lin_model.fit(X_train, y_train): \n', lin_model.fit(X_train, y_train))
# Out:
# lin_model.fit(X_train, y_train):
#  LinearRegression()

# %%
plt.title('Distribución de los valores de X')
plt.xlabel('Valores de X')
plt.ylabel('Valores de Y')
plt.plot(x_1,y, color = 'blue', label = 'X_1')
plt.plot(x_2,y, color = 'red', label = 'X_2')
plt.plot(x_3,y, color = 'orange', label = 'X_3')
plt.legend()
plt.grid()
plt.show()

# %%
print(df['X1'][0])
print(df['X1'][1499])
print(df['X2'][0])
print(df['X2'][1499])
print(df['X3'][0])
print(df['X3'][1499])
# Out:
# -10.0
# 10.0
# 0.0
# 22.0
# -5.0
# 0.0

# %%
X_1_pendiente = np.linspace(-10,10,1500)
X_2_pendiente = np.linspace(0,22,1500)
X_3_pendiente = np.linspace(-5,0,1500)

# %%
from sklearn.metrics import r2_score

# %%
y_test = np.array(y_test).reshape(-1,1)
X_test = np.array(X_test).reshape(-1,1)
print(y_test.shape)
print(X_test.shape)
print(X_train.shape)
# Out:
# (300, 1)
# (300, 1)
# (1200, 1)

# %%
y_test_predict = lin_model.predict(X_test)
r2 = r2_score(y_test, y_test_predict)
print('The model performance for testing set is: ')
print('\n#########################################\n')
print('R2 score is {}'. format(r2))
# Out:
# The model performance for testing set is:
#
# #########################################
#
# R2 score is 0.8674696631382686

# %% [markdown]
# ### Ecuación de la recta y = mX + b

# %%
print('Coeffient:\n', lin_model.coef_)
print('Independent term: \n', lin_model.intercept_)
# Out:
# Coeffient:
#  [[-0.45103719]]
# Independent term:
#  [5.48556154]

# %% [markdown]
# ### Recta de regresión lineal simple
#
# Ahora toca dibujar la recta con los valores que predice nuestro modelo

# %%
x_1 = np.array(x_1).reshape(-1,1)
x_2 = np.array(x_2).reshape(-1,1)
x_3 = np.array(x_3).reshape(-1,1)

# %%
## Recordar que le tenemos que hacer el reshape porque si no, nos arroja un error de dimensionalidad.
y = np.array(y).reshape(-1,1)
predicted_data_valores = lin_model.predict(x_1)
## Para hacer estas dos predicciones correctamente, tiene que estar el modelo 
## entrenado con respecto a cada variable x_2 y x_3 respectivamente
predicted_data_valores_2 = lin_model.predict(x_2)
predicted_data_valores_3 = lin_model.predict(x_3)

# %%
plt.scatter(x_1, y, label = 'x1', color = 'blue')
plt.scatter(x_2, y, label = 'x2', color = 'red')
plt.scatter(x_3, y, label = 'x3', color = 'orange')
plt.plot(x_1, predicted_data_valores, '--', color = 'black', label = 'X1_regression')
#plt.plot(x_2, predicted_data_valores_2, '--', color = 'green', label = 'X2_regression')
#plt.plot(x_3, predicted_data_valores_3, '--', color = 'red', label = 'X3_regression')
plt.title('Valores de X con respecto a y')
plt.xlabel('Valores de x')
plt.ylabel('Valores de y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Nos creamos un dataframe con los valores predichos

# %%
df1 = pd.DataFrame({'Real': x_1, 'Predicción': predicted_data_valores})
df1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10372\2912430274.py in <module>
# ----> 1 df1 = pd.DataFrame({'Real': x_1, 'Predicción': predicted_data_valores})
#       2 df1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     634         elif isinstance(data, dict):
#     635             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637         elif isinstance(data, ma.MaskedArray):
#     638             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     500         # TODO: can we get rid of the dt64tz special case above?
#     501
# ...

# %%
x_1 = np.array(x_1).reshape(-1,)

# %%
predicted_data_valores = np.array(predicted_data_valores).reshape(-1,)

# %%
x_1.shape
# Out:
# (1500,)

# %%
y = np.array(y).reshape(-1,)

# %%
predicted_data_valores.shape
# Out:
# (1500,)

# %%
df1 = pd.DataFrame({'Real': y, 'Predicción': predicted_data_valores})
df1
# Out:
#            Real  Predicción
# 0     10.958481    9.995933
# 1      8.991666    9.989916
# 2     10.398068    9.983898
# 3     11.759961    9.977880
# 4     10.177304    9.971862
# ...         ...         ...
# 1495   1.208277    0.999261
# 1496   1.814573    0.993243
# 1497   0.791170    0.987225
# 1498   1.207057    0.981207
# 1499   0.993813    0.975190
#
# [1500 rows x 2 columns]

# %%
df1.head(15).plot(kind = 'bar')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import sklearn.datasets
dsBoston = sklearn.datasets.load_boston()
dsBoston
# Out:
# C:\Users\Alfredo\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
# ...

# %%
dfBoston = pd.DataFrame(dsBoston.data, columns = dsBoston.feature_names)
dfBoston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
dfBoston.shape
# Out:
# (506, 13)

# %%
dsBoston.DESCR
# Out:
# ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate per $10,0
# ...

# %%
## Datos guardados en el dataset de target
dsBoston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
dfBoston['MEDV'] = dsBoston.target
dfBoston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
dsBoston.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %%
dfBoston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
sns.displot(dfBoston['MEDV'], bins = 50)
plt.show()

# %%
correlation_matrix_boston = dfBoston.corr().round(2)
correlation_matrix_boston
# Out:
#          CRIM    ZN  INDUS  CHAS   NOX    RM   AGE   DIS   RAD   TAX  PTRATIO  \
# CRIM     1.00 -0.20   0.41 -0.06  0.42 -0.22  0.35 -0.38  0.63  0.58     0.29
# ZN      -0.20  1.00  -0.53 -0.04 -0.52  0.31 -0.57  0.66 -0.31 -0.31    -0.39
# INDUS    0.41 -0.53   1.00  0.06  0.76 -0.39  0.64 -0.71  0.60  0.72     0.38
# CHAS    -0.06 -0.04   0.06  1.00  0.09  0.09  0.09 -0.10 -0.01 -0.04    -0.12
# NOX      0.42 -0.52   0.76  0.09  1.00 -0.30  0.73 -0.77  0.61  0.67     0.19
# RM      -0.22  0.31  -0.39  0.09 -0.30  1.00 -0.24  0.21 -0.21 -0.29    -0.36
# AGE      0.35 -0.57   0.64  0.09  0.73 -0.24  1.00 -0.75  0.46  0.51     0.26
# DIS     -0.38  0.66  -0.71 -0.10 -0.77  0.21 -0.75  1.00 -0.49 -0.53    -0.23
# RAD      0.63 -0.31   0.60 -0.01  0.61 -0.21  0.46 -0.49  1.00  0.91     0.46
# TAX      0.58 -0.31   0.72 -0.04  0.67 -0.29  0.51 -0.53  0.91  1.00     0.46
# PTRATIO  0.29 -0.39   0.38 -0.12  0.19 -0.36  0.26 -0.23  0.46  0.46     1.00
# ...

# %% [markdown]
# ### Mapa de calor
#
# El mapa de calor nos va a servir para ver la correlación que tienen entre las variables.
#
# `¿Pero para qué queremos saber esto?`
#
# Con estos datos, podemos entender porque una variable va cambiando con respecto a la otra. Supongamos que queremos hacer un modelo de Machine Learning que sea del tipo regresión lineal, acá podemos ver de una manera gráfica y bien descriptiva cuál variable nos conviene elegir a la hora de construir el modelo.

# %%
sns.heatmap(data = correlation_matrix_boston, annot = True)
## Para aumentar el tamaño del mapa:
plt.rcParams['figure.figsize'] = (15,5)
plt.show()

# %% [markdown]
# ### Análisis del scatterplot
#
# * Se ve que a medida que a más habitaciones, el precio de la casa aumenta.
# * Hay una gran acumulación de casas entre 5 y 7 habitaciones

# %%
plt.scatter(dfBoston['RM'], dfBoston['MEDV'])
plt.title('Precio vs Habitaciones')
plt.xlabel('N° de Habitaciones')
plt.ylabel('Precio')
plt.show()

# %%
sns.displot(dfBoston['RM'], bins = 50)
plt.show()

# %%
print('Maximo valor: {}'. format(dfBoston['MEDV'].max()))
print('Mínimo valor: {}'. format(dfBoston['MEDV'].max()))
print('Mean: {}'. format(dfBoston['MEDV'].max()))
print('Std: {}'. format(dfBoston['MEDV'].max()))
# Out:
# Maximo valor: 50.0
# Mínimo valor: 50.0
# Mean: 50.0
# Std: 50.0

# %%
X_featureRM = dfBoston['RM']
y_priceMEDV = dfBoston['MEDV']
x_train, X_test, y_train, y_test = train_test_split(X_featureRM, y_priceMEDV, test_size = 0.2, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1200, 1)
# (102,)
# (404,)
# (102,)

# %%
plt.scatter(dfBoston['LSTAT'], dfBoston['MEDV'])
plt.title('Precio vs LSTAT')
plt.xlabel('LSTAT')
plt.rcParams['figure.figsize'] = (5,5)
plt.ylabel('Precio')
plt.show()

# %%
print('Maximo valor {}'.format(dfBoston['MEDV'].max()))
print('Maximo valor {}'.format(dfBoston['MEDV'].min()))
print('Mean {}'.format(dfBoston['MEDV'].mean()))
print('Median {}'.format(dfBoston['MEDV'].median()))
print('Std {}'.format(dfBoston['MEDV'].std()))
# Out:
# Maximo valor 50.0
# Maximo valor 5.0
# Mean 22.532806324110698
# Median 21.2
# Std 9.19710408737982

# %%
X_featureRM = dfBoston['RM']
y_priceMEDV = dfBoston['MEDV']
X_train, X_test, y_train, y_test = train_test_split(X_featureRM, y_priceMEDV, test_size = 0.2, random_state = 42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404,)
# (102,)
# (404,)
# (102,)

# %%
lin_model_boston = LinearRegression()
lin_model_boston.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10372\2950689995.py in <module>
#       1 lin_model_boston = LinearRegression()
# ----> 2 lin_model_boston.fit(X_train, y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     660         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     661
# --> 662         X, y = self._validate_data(
#     663             X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664         )
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ...

# %%
## Nos da el error de que tenemos que hacerle el reshape al array
X_train = np.array(X_train).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)

# %%
lin_model_boston = LinearRegression()
lin_model_boston.fit(X_train, y_train)
print('Coefficients: \n', lin_model_boston.coef_)
print('Independent term: \n', lin_model_boston.intercept_)
# Out:
# Coefficients:
#  [[9.34830141]]
# Independent term:
#  [-36.2463189]

# %% [markdown]
# * Coefficients: Es la pendiente y significa que cada vez que aumenta en 1 la habitación, aumenta en 9.3483 el valor de la vivienda.
#
# * Independent term: es el valor en donde corta con la y. En este caso es -36.24

# %% [markdown]
# ### Evaluación del modelo

# %%
y_train = np.array(y_train).reshape(-1,1)
y_test_predict = np.array(y_test_predict).reshape(-1,1)

# %%
y_train_predict = lin_model_boston.predict(X_train)
r2 = r2_score(y_train, y_train_predict)
print('The model performance for training set')
print('--------------------------------------')
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# R2 score is 0.5050658352776293

# %%
X_test = np.array(X_test).reshape(-1,1)

# %%
y_test_predict = lin_model_boston.predict(X_test)
r2 = r2_score(y_test, y_test_predict)
print('The model performance for training set')
print('--------------------------------------')
print('R2 score is {}'.format(r2))
# Out:
# The model performance for training set
# --------------------------------------
# R2 score is 0.3707569232254778

# %% [markdown]
# ## Viendo visualmente nuestro modelo

# %%
predicted_data_boston = lin_model_boston.predict(dfBoston[['RM']])
predicted_data_boston[0:5]
# Out:
# C:\Users\Alfredo\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# array([[25.21876285],
#        [23.77912443],
#        [30.92122671],
#        [29.17309434],
#        [30.56599125]])

# %%
plt.scatter(dfBoston['RM'], dfBoston['MEDV'])
plt.plot(dfBoston['RM'], predicted_data_boston, color = 'red')
plt.title('Precio vs Habitaciones')
plt.xlabel('Habitaciones')
plt.rcParams['figure.figsize'] = (5,5)
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# ## Más sobre nuestro modelo

# %% [markdown]
# Datos de entrenamiento

# %%
#X_train, X_test, y_train, y_test
plt.scatter(X_train, y_train)
plt.plot(dfBoston['RM'], predicted_data_boston, color = 'red')
plt.title('Precio vs Habitaciones')
plt.xlabel('Habitaciones')
plt.rcParams['figure.figsize'] = (5,5)
plt.ylabel('Precio')
plt.show()

# %% [markdown]
# Datos de testeo

# %%
#X_train, X_test, y_train, y_test
plt.scatter(X_test, y_test)
plt.plot(dfBoston['RM'], predicted_data_boston, color = 'red')
plt.title('Precio vs Habitaciones')
plt.xlabel('Habitaciones')
plt.rcParams['figure.figsize'] = (5,5)
plt.ylabel('Precio')
plt.show()

# %%
predicted_data_boston = predicted_data_boston.flatten()
boston_MEDV = np.array(dfBoston['MEDV']).flatten()

# %%
dfAP = pd.DataFrame({'Actual': dfBoston['MEDV'], 'Predicción':predicted_data_boston})
dfAP.head(10)
# Out:
#    Actual  Predicción
# 0    24.0   25.218763
# 1    21.6   23.779124
# 2    34.7   30.921227
# 3    33.4   29.173094
# 4    36.2   30.565991
# 5    28.7   23.863259
# 6    22.9   19.955669
# 7    27.1   21.451397
# 8    16.5   16.393966
# 9    18.9   19.880883

# %%
dfAP.head(15).plot(kind = 'bar')
plt.show()

# %%
predicted_data_boston.flatten().shape
# Out:
# (506,)
